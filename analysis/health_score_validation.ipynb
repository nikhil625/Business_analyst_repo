# %% [markdown]
# # Health Score Validation
#
# Export `customer_health_scores` from MySQL and use this notebook to validate churn, upgrade, and revenue differences across health segments.

# %%
import pandas as pd
import numpy as np
from scipy import stats

# df = pd.read_csv('customer_health_scores.csv')
# df.head()

# %% [markdown]
# ## Segment Summary

# %%
# summary = df.groupby('health_segment').agg(
#     customers=('customer_id', 'nunique'),
#     avg_health_score=('health_score', 'mean'),
#     churn_rate=('churned_currently_flag', 'mean'),
#     avg_mrr=('mrr', 'mean')
# ).reset_index()
# summary
